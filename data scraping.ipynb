# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import json
import re
import os
from time import sleep
from collections import defaultdict
import pandas as pd
from dotenv import load_dotenv
load_dotenv('.env')
# Out:
# True

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
root_url = 'https://www.billboard.com/charts/year-end/{}/hot-100-songs'
years = {i:{} for i in range(2020, 1989, -1)}
for y in years:
    url = root_url.format(y)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    chart_titles = [f.text.strip() for f in soup.find_all('div', {"class": 'ye-chart-item__title'})]
    artists = [f.text.strip() for f in soup.find_all('div', {"class": 'ye-chart-item__artist'})]
    assert len(chart_titles) == len(artists)
    years[y] = {chart_titles[i]:artists[i] for i in range(len(chart_titles))}
json.dump(years, open('data/billboard-top100.json','w'), indent=2)

# %%
data = {}

# %%
def clean_str(st, lower=True, splt=[], rplc={}):
    st = st.encode("ascii", "ignore").decode()
    if lower: st = st.lower()
    for k,v in rplc.items():
        st = st.replace(k,v)
    for s in splt:
        st = st.split(s)[0]
    st = re.sub(r'[^\w\s]', '', st)
    st = re.sub('\s+',' ',st)
    return st.strip()
    
def scrape_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    #remove identifiers like chorus, verse, etc
    lyrics = re.sub(r'[\(\[].*?[\)\]]', '', lyrics)
    #remove empty lines
    lyrics = os.linesep.join([s for s in lyrics.splitlines() if s])         
    return lyrics

# %%
def scrape_song_album(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    song_name = html.find('h1', class_='header_with_cover_art-primary_info-title').get_text()
    album_name = html.find('a', class_='header_with_cover_art-primary_info-primary_artist').get_text()
    return song_name, album_name

# %%
song_lyrics_root_url = 'https://genius.com/{}-lyrics'
for y,year_d in years.items():
#     print('.', end='')
    for i,(k,v) in enumerate(year_d.items()):
        song_key = '-'.join(clean_str(k).split(' '))
        artist_key = '-'.join(clean_str(v).split(' '))
#         artist_key = artist_key.split('-featuring')[0]
        full_key = artist_key + '-' + song_key
        if full_key in data: data[full_key]['billboard_rankings'][y] = i
        else:
            url = song_lyrics_root_url.format(full_key)
            data[full_key] = {'billboard_rankings':{y:i}, 'song': k, 'artist': v, 'genius_url':url}
            try:
                data[full_key]['lyrics'] = scrape_song_lyrics(url)
            except Exception as e:
                data[full_key]['lyrics'] = '--ERROR--'
# Out:
# https://genius.com/gucci-mane-and-bruno-mars-and-kodak-black-wake-up-in-the-sky-lyrics ------ Wake Up In The Sky ------ Gucci Mane X Bruno Mars X Kodak Black
# wake-up-in-the-sky ------ gucci-mane-and-bruno-mars-and-kodak-black
#
# https://genius.com/young-thug-j-cole-and-travis-scott-the-london-lyrics ------ The London ------ Young Thug, J. Cole & Travis Scott
# the-london ------ young-thug-j-cole-and-travis-scott
#
# https://genius.com/daddy-yankee-and-katy-perry-con-calma-lyrics ------ Con Calma ------ Daddy Yankee & Katy Perry Featuring Snow
# con-calma ------ daddy-yankee-and-katy-perry
#
# https://genius.com/lil-baby-and-dababy-baby-lyrics ------ Baby ------ Lil Baby & DaBaby
# baby ------ lil-baby-and-dababy
#
# https://genius.com/megan-thee-stallion-nicki-minaj-and-ty-dolla-ign-hot-girl-summer-lyrics ------ Hot Girl Summer ------ Megan Thee Stallion, Nicki Minaj & Ty Dolla $ign
# hot-girl-summer ------ megan-thee-stallion-nicki-minaj-and-ty-dolla-ign
#
# https://genius.com/pnk-walk-me-home-lyrics ------ Walk Me Home ------ P!nk
# walk-me-home ------ pnk
#
# https://genius.com/bruno-mars-and-cardi-b-finesse-lyrics ------ Finesse ------ Bruno Mars & Cardi B
# finesse ------ bruno-mars-and-cardi-b
#
# https://genius.com/marshmello-and-annemarie-friends-lyrics ------ Friends ------ Marshmello & Anne-Marie
# friends ------ marshmello-and-annemarie
#
# https://genius.com/geazy-no-limit-lyrics ------ No Limit ------ G-Eazy Featuring A$AP Rocky & Cardi B
# no-limit ------ geazy
#
# https://genius.com/geazy-and-halsey-him-and-i-lyrics ------ Him & I ------ G-Eazy & Halsey
# him-and-i ------ geazy-and-halsey
#
# https://genius.com/cardi-b-bodak-yellow-money-moves-lyrics ------ Bodak Yellow (Money Moves) ------ Cardi B
# bodak-yellow-money-moves ------ cardi-b
#
# https://genius.com/aap-ferg-plain-jane-lyrics ------ Plain Jane ------ A$AP Ferg Featuring Nicki Minaj
# plain-jane ------ aap-ferg
#
# https://genius.com/casper-magico-nio-garcia-darell-nicky-jam-ozuna-and-bad-bunny-te-bote-lyrics ------ Te Bote ------ Casper Magico, Nio Garcia, Darell, Nicky Jam, Ozuna & Bad Bunny
# te-bote ------ casper-magico-nio-garcia-darell-nicky-jam-ozuna-and-bad-bunny
#
# https://genius.com/logic-18002738255-lyrics ------ 1-800-273-8255 ------ Logic Featuring Alessia Cara & Khalid
# 18002738255 ------ logic
#
# https://genius.com/rae-sremmurd-and-juicy-j-powerglide-lyrics ------ Powerglide ------ Rae Sremmurd & Juicy J
# powerglide ------ rae-sremmurd-and-juicy-j
#
# https://genius.com/luis-fonsi-and-daddy-yankee-despacito-lyrics ------ Despacito ------ Luis Fonsi & Daddy Yankee Featuring Justin Bieber
# despacito ------ luis-fonsi-and-daddy-yankee
#
# https://genius.com/cardi-b-bodak-yellow-money-moves-lyrics ------ Bodak Yellow (Money Moves) ------ Cardi B
# bodak-yellow-money-moves ------ cardi-b
#
# https://genius.com/zayn-taylor-swift-i-dont-wanna-live-forever-fifty-shades-darker-lyrics ------ I Don't Wanna Live Forever (Fifty Shades Darker) ------ Zayn / Taylor Swift
# i-dont-wanna-live-forever-fifty-shades-darker ------ zayn-taylor-swift
#
# https://genius.com/logic-18002738255-lyrics ------ 1-800-273-8255 ------ Logic Featuring Alessia Cara & Khalid
# 18002738255 ------ logic
#
# https://genius.com/migos-tshirt-lyrics ------ T-Shirt ------ Migos
# tshirt ------ migos
#
# https://genius.com/zay-hilfigerrr-and-zayion-mccall-juju-on-that-beat-tz-anthem-lyrics ------ Juju On That Beat (TZ Anthem) ------ Zay Hilfigerrr & Zayion McCall
# juju-on-that-beat-tz-anthem ------ zay-hilfigerrr-and-zayion-mccall
#
# https://genius.com/pnk-what-about-us-lyrics ------ What About Us ------ P!nk
# what-about-us ------ pnk
#
# https://genius.com/geazy-and-bebe-rexha-me-myself-and-i-lyrics ------ Me, Myself & I ------ G-Eazy x Bebe Rexha
# me-myself-and-i ------ geazy-and-bebe-rexha
#
# https://genius.com/pnk-just-like-fire-lyrics ------ Just Like Fire ------ P!nk
# just-like-fire ------ pnk
#
# https://genius.com/pitbull-and-neyo-time-of-our-lives-lyrics ------ Time Of Our Lives ------ Pitbull & Ne-Yo
# time-of-our-lives ------ pitbull-and-neyo
#
# https://genius.com/big-sean-i-dont-fk-with-you-lyrics ------ I Don't F**k With You ------ Big Sean Featuring E-40
# i-dont-fk-with-you ------ big-sean
#
# https://genius.com/rihanna-b-better-have-my-money-lyrics ------ B**** Better Have My Money ------ Rihanna
# b-better-have-my-money ------ rihanna
#
# https://genius.com/twayne-nasty-freestyle-lyrics ------ Nasty Freestyle ------ T-Wayne
# nasty-freestyle ------ twayne
#
# https://genius.com/beyonce-711-lyrics ------ 7/11 ------ Beyonce
# 711 ------ beyonce
#
# https://genius.com/nicky-jam-and-enrique-iglesias-el-perdon-forgiveness-lyrics ------ El Perdon (Forgiveness) ------ Nicky Jam & Enrique Iglesias
# el-perdon-forgiveness ------ nicky-jam-and-enrique-iglesias
#
# https://genius.com/neyo-she-knows-lyrics ------ She Knows ------ Ne-Yo Featuring Juicy J
# she-knows ------ neyo
#
# https://genius.com/bobby-shmurda-hot-boy-lyrics ------ Hot Boy ------ Bobby Shmurda
# hot-boy ------ bobby-shmurda
#
# https://genius.com/mike-will-madeit-23-lyrics ------ 23 ------ Mike WiLL Made-It Featuring Miley Cyrus, Wiz Khalifa & Juicy J
# 23 ------ mike-will-madeit
#
# https://genius.com/pnk-just-give-me-a-reason-lyrics ------ Just Give Me A Reason ------ P!nk Featuring Nate Ruess
# just-give-me-a-reason ------ pnk
#
# https://genius.com/anna-kendrick-cups-pitch-perfects-when-im-gone-lyrics ------ Cups (Pitch Perfect's When I'm Gone) ------ Anna Kendrick
# cups-pitch-perfects-when-im-gone ------ anna-kendrick
#
# https://genius.com/william-and-britney-spears-scream-and-shout-lyrics ------ Scream & Shout ------ will.i.am & Britney Spears
# scream-and-shout ------ william-and-britney-spears
#
# https://genius.com/aap-rocky-fkin-problems-lyrics ------ F**kin Problems ------ A$AP Rocky Featuring Drake, 2 Chainz & Kendrick Lamar
# fkin-problems ------ aap-rocky
#
# https://genius.com/lana-del-rey-and-cedric-gervais-summertime-sadness-lyrics ------ Summertime Sadness ------ Lana Del Rey & Cedric Gervais
# summertime-sadness ------ lana-del-rey-and-cedric-gervais
#
# https://genius.com/pnk-try-lyrics ------ Try ------ P!nk
# try ------ pnk
#
# https://genius.com/keha-die-young-lyrics ------ Die Young ------ Ke$ha
# die-young ------ keha
#
# https://genius.com/neyo-let-me-love-you-until-you-learn-to-love-yourself-lyrics ------ Let Me Love You (Until You Learn To Love Yourself) ------ Ne-Yo
# let-me-love-you-until-you-learn-to-love-yourself ------ neyo
#
# https://genius.com/kanye-west-big-sean-pusha-t-2-chainz-mercy-lyrics ------ Mercy ------ Kanye West, Big Sean, Pusha T, 2 Chainz
# mercy ------ kanye-west-big-sean-pusha-t-2-chainz
#
# https://genius.com/pnk-blow-me-one-last-kiss-lyrics ------ Blow Me (One Last Kiss) ------ P!nk
# blow-me-one-last-kiss ------ pnk
#
# https://genius.com/jay-z-kanye-west-nias-in-paris-lyrics ------ Ni**as in Paris ------ Jay Z Kanye West
# nias-in-paris ------ jay-z-kanye-west
#
# https://genius.com/neyo-let-me-love-you-until-you-learn-to-love-yourself-lyrics ------ Let Me Love You (Until You Learn To Love Yourself) ------ Ne-Yo
# let-me-love-you-until-you-learn-to-love-yourself ------ neyo
#
# https://genius.com/keha-die-young-lyrics ------ Die Young ------ Ke$ha
# die-young ------ keha
#
# https://genius.com/tpain-5-oclock-lyrics ------ 5 O'Clock ------ T-Pain Featuring Wiz Khalifa & Lily Allen
# 5-oclock ------ tpain
#
# https://genius.com/cah-out-cashin-out-lyrics ------ Cashin' Out ------ Ca$h Out
# cashin-out ------ cah-out
#
# https://genius.com/rihanna-sandm-lyrics ------ S&M ------ Rihanna
# sandm ------ rihanna
#
# https://genius.com/pnk-raise-your-glass-lyrics ------ Raise Your Glass ------ P!nk
# raise-your-glass ------ pnk
#
# https://genius.com/pnk-fkin-perfect-lyrics ------ F**kin' Perfect ------ P!nk
# fkin-perfect ------ pnk
#
# https://genius.com/keha-we-r-who-we-r-lyrics ------ We R Who We R ------ Ke$ha
# we-r-who-we-r ------ keha
#
# https://genius.com/keha-blow-lyrics ------ Blow ------ Ke$ha
# blow ------ keha
#
# https://genius.com/edward-maya-and-vika-jigulina-stereo-love-lyrics ------ Stereo Love ------ Edward Maya & Vika Jigulina
# stereo-love ------ edward-maya-and-vika-jigulina
#
# https://genius.com/fareast-movement-rocketeer-lyrics ------ Rocketeer ------ Far*East Movement Featuring Ryan Tedder
# rocketeer ------ fareast-movement
#
# https://genius.com/fareast-movement-like-a-g6-lyrics ------ Like A G6 ------ Far*East Movement Featuring Cataracs & Dev
# like-a-g6 ------ fareast-movement
# https://genius.com/keha-tik-tok-lyrics ------ TiK ToK ------ Ke$ha
# tik-tok ------ keha
#
# https://genius.com/jayz-alicia-keys-empire-state-of-mind-lyrics ------ Empire State Of Mind ------ Jay-Z + Alicia Keys
# empire-state-of-mind ------ jayz-alicia-keys
#
# https://genius.com/keha-your-love-is-my-drug-lyrics ------ Your Love Is My Drug ------ Ke$ha
# your-love-is-my-drug ------ keha
#
# https://genius.com/fareast-movement-like-a-g6-lyrics ------ Like A G6 ------ Far*East Movement Featuring Cataracs & Dev
# like-a-g6 ------ fareast-movement
#
# https://genius.com/jayz-mr-hudson-young-forever-lyrics ------ Young Forever ------ Jay-Z + Mr. Hudson
# young-forever ------ jayz-mr-hudson
#
# https://genius.com/keha-blah-blah-blah-lyrics ------ Blah Blah Blah ------ Ke$ha Featuring 3OH!3
# blah-blah-blah ------ keha
#
# https://genius.com/keha-take-it-off-lyrics ------ Take It Off ------ Ke$ha
# take-it-off ------ keha
#
# https://genius.com/3oh3-my-first-kiss-lyrics ------ My First Kiss ------ 3OH!3 Featuring Ke$ha
# my-first-kiss ------ 3oh3
#
# https://genius.com/alicia-keys-unthinkable-im-ready-lyrics ------ Un-Thinkable (I'm Ready) ------ Alicia Keys
# unthinkable-im-ready ------ alicia-keys
#
# https://genius.com/the-allamerican-rejects-gives-you-hell-lyrics ------ Gives You Hell ------ The All-American Rejects
# gives-you-hell ------ the-allamerican-rejects
#
# https://genius.com/kid-cudi-day-n-nite-lyrics ------ Day 'N' Nite ------ Kid Cudi
# day-n-nite ------ kid-cudi
#
# https://genius.com/3oh3-dont-trust-me-lyrics ------ Don't Trust Me ------ 3OH!3
# dont-trust-me ------ 3oh3
#
# https://genius.com/jayz-rihanna-and-kanye-west-run-this-town-lyrics ------ Run This Town ------ Jay-Z, Rihanna & Kanye West
# run-this-town ------ jayz-rihanna-and-kanye-west
#
# https://genius.com/pnk-sober-lyrics ------ Sober ------ P!nk
# sober ------ pnk
#
# https://genius.com/neyo-mad-lyrics ------ Mad ------ Ne-Yo
# mad ------ neyo
#
# https://genius.com/pnk-so-what-lyrics ------ So What ------ P!nk
# so-what ------ pnk
#
# https://genius.com/eminem-dr-dre-and-50-cent-crack-a-bottle-lyrics ------ Crack A Bottle ------ Eminem, Dr. Dre & 50 Cent
# crack-a-bottle ------ eminem-dr-dre-and-50-cent
#
# https://genius.com/pnk-please-dont-leave-me-lyrics ------ Please Don't Leave Me ------ P!nk
# please-dont-leave-me ------ pnk
#
# https://genius.com/neyo-miss-independent-lyrics ------ Miss Independent ------ Ne-Yo
# miss-independent ------ neyo
#
# https://genius.com/jayz-alicia-keys-empire-state-of-mind-lyrics ------ Empire State Of Mind ------ Jay-Z + Alicia Keys
# empire-state-of-mind ------ jayz-alicia-keys
#
# https://genius.com/soulja-boy-tellem-turn-my-swag-on-lyrics ------ Turn My Swag On ------ Soulja Boy Tell'em
# turn-my-swag-on ------ soulja-boy-tellem
#
# https://genius.com/thedream-rockin-that-thang-lyrics ------ Rockin' That Thang ------ The-Dream
# rockin-that-thang ------ thedream
#
# https://genius.com/jim-jones-and-ron-browz-pop-champagne-lyrics ------ Pop Champagne ------ Jim Jones & Ron Browz Featuring Juelz Santana
# pop-champagne ------ jim-jones-and-ron-browz
#
# https://genius.com/ray-j-and-yung-berg-sexy-can-i-lyrics ------ Sexy Can I ------ Ray J & Yung Berg
# sexy-can-i ------ ray-j-and-yung-berg
#
# https://genius.com/neyo-closer-lyrics ------ Closer ------ Ne-Yo
# closer ------ neyo
#
# https://genius.com/pnk-so-what-lyrics ------ So What ------ P!nk
# so-what ------ pnk
#
# https://genius.com/tpain-cant-believe-it-lyrics ------ Can't Believe It ------ T-Pain Featuring Lil Wayne
# cant-believe-it ------ tpain
#
# https://genius.com/soulja-boy-tellem-crank-that-soulja-boy-lyrics ------ Crank That (Soulja Boy) ------ Soulja Boy Tell'em
# crank-that-soulja-boy ------ soulja-boy-tellem
#
# https://genius.com/neyo-miss-independent-lyrics ------ Miss Independent ------ Ne-Yo
# miss-independent ------ neyo
#
# https://genius.com/thedream-i-luv-your-girl-lyrics ------ I Luv Your Girl ------ The-Dream
# i-luv-your-girl ------ thedream
#
# https://genius.com/tpain-buy-u-a-drank-shawty-snappin-lyrics ------ Buy U A Drank (Shawty Snappin') ------ T-Pain Featuring Yung Joc
# buy-u-a-drank-shawty-snappin ------ tpain
#
# https://genius.com/soulja-boy-tellem-crank-that-soulja-boy-lyrics ------ Crank That (Soulja Boy) ------ Soulja Boy Tell'em
# crank-that-soulja-boy ------ soulja-boy-tellem
#
# https://genius.com/justin-timberlake-what-goes-aroundcomes-around-lyrics ------ What Goes Around...Comes Around ------ Justin Timberlake
# what-goes-aroundcomes-around ------ justin-timberlake
#
# https://genius.com/gym-class-heroes-cupids-chokeholdbreakfast-in-america-lyrics ------ Cupid's Chokehold/Breakfast In America ------ Gym Class Heroes Featuring Patrick Stump
# cupids-chokeholdbreakfast-in-america ------ gym-class-heroes
#
# https://genius.com/pnk-u-ur-hand-lyrics ------ U + Ur Hand ------ P!nk
# u-ur-hand ------ pnk
#
# https://genius.com/tpain-bartender-lyrics ------ Bartender ------ T-Pain Featuring Akon
# bartender ------ tpain
#
# https://genius.com/justin-timberlake-summer-love-lyrics ------ Summer Love ------ Justin Timberlake
# summer-love ------ justin-timberlake
#
# https://genius.com/r-kelly-or-bow-wow-im-a-flirt-lyrics ------ I'm A Flirt ------ R. Kelly Or Bow Wow (Featuring T.I. & T-Pain)
# im-a-flirt ------ r-kelly-or-bow-wow
#
# https://genius.com/the-allamerican-rejects-it-ends-tonight-lyrics ------ It Ends Tonight ------ The All-American Rejects
# it-ends-tonight ------ the-allamerican-rejects
#
# https://genius.com/neyo-because-of-you-lyrics ------ Because Of You ------ Ne-Yo
# because-of-you ------ neyo
#
# https://genius.com/bone-thugsnharmony-i-tried-lyrics ------ I Tried ------ Bone Thugs-N-Harmony Featuring Akon
# i-tried ------ bone-thugsnharmony
#
# https://genius.com/pnk-who-knew-lyrics ------ Who Knew ------ P!nk
# who-knew ------ pnk
#
# https://genius.com/ti-big-things-poppin-do-it-lyrics ------ Big Things Poppin' (Do It) ------ T.I.
# big-things-poppin-do-it ------ ti
#
# https://genius.com/rihanna-and-sean-paul-break-it-off-lyrics ------ Break It Off ------ Rihanna & Sean Paul
# break-it-off ------ rihanna-and-sean-paul
#
# https://genius.com/justin-timberlake-lovestoned-lyrics ------ LoveStoned ------ Justin Timberlake
# lovestoned ------ justin-timberlake
#
# https://genius.com/snoop-dogg-thats-that-lyrics ------ That's That ------ Snoop Dogg Featuring R. Kelly
# thats-that ------ snoop-dogg
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
#
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/neyo-so-sick-lyrics ------ So Sick ------ Ne-Yo
# so-sick ------ neyo
#
# https://genius.com/the-allamerican-rejects-move-along-lyrics ------ Move Along ------ The All-American Rejects
# move-along ------ the-allamerican-rejects
# https://genius.com/tpain-im-n-luv-wit-a-stripper-lyrics ------ I'm N Luv (Wit A Stripper) ------ T-Pain Featuring Mike Jones
# im-n-luv-wit-a-stripper ------ tpain
#
# https://genius.com/the-allamerican-rejects-dirty-little-secret-lyrics ------ Dirty Little Secret ------ The All-American Rejects
# dirty-little-secret ------ the-allamerican-rejects
#
# https://genius.com/neyo-sexy-love-lyrics ------ Sexy Love ------ Ne-Yo
# sexy-love ------ neyo
#
# https://genius.com/e40-u-and-dat-lyrics ------ U And Dat ------ E-40 Featuring T-Pain & Kandi Girl
# u-and-dat ------ e40
#
# https://genius.com/sean-paul-we-be-burnin-lyrics ------ We Be Burnin' ------ Sean Paul
# we-be-burnin ------ sean-paul
#
# https://genius.com/neyo-when-youre-mad-lyrics ------ When You're Mad ------ Ne-Yo
# when-youre-mad ------ neyo
#
# https://genius.com/pnk-stupid-girls-lyrics ------ Stupid Girls ------ P!nk
# stupid-girls ------ pnk
#
# https://genius.com/tpain-im-sprung-lyrics ------ I'm Sprung ------ T-Pain
# im-sprung ------ tpain
#
# https://genius.com/soul-ii-soul-back-to-life-lyrics ------ Back To Life ------ Soul II Soul
# back-to-life ------ soul-ii-soul
#
# https://genius.com/kyper-tictactoe-lyrics ------ Tic-Tac-Toe ------ Kyper
# tictactoe ------ kyper

# %%
for i,(key,key_data) in enumerate(data.items()):
    try:
        song_name, album_name = scrape_song_album(key_data['song_genius_url'])
        data[key]['song'] = song_name
        data[key]['artist'] = album_name
    except Exception as e:
        print(key)
        continue
    if album_name in key_data:
        del data[key]['album_name']
    if i%10==0: print('.', end='')
# Out:
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
for i, (key,key_data) in enumerate(data.items()):
    try:
        data[key]['song_lyrics'] = scrape_song_lyrics(key_data['song_genius_url'])
    except Exception as e:
        print(key)
        continue
    if i%10==0: print('.', end='')

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
exception_keys = []
for i, (key,key_data) in enumerate(data.items()):
    artist = key_data['artist']
    song = key_data['song']
    results = spotify.search(q='artist:' + artist + ' track:' + song, type='track')
    try:
        track = results['tracks']['items'][0]
    except Exception as e:
        results = spotify.search(q=song + ' ' + artist, type='track')
        try:
            track = results['tracks']['items'][0]
        except Exception as e:
            exception_keys.append(key)
            continue
    data[key]['album_name'] = track['album']['name']
    data[key]['album_id'] = track['album']['id']
    data[key]['album_total_tracks'] = track['album']['total_tracks']
    data[key]['song_duration'] = track['duration_ms']
    data[key]['song_explicit'] = track['explicit']
    data[key]['song_id'] = track['id']
    data[key]['song_popularity'] = track['popularity']
    if i%10==0: print('.', end='')
# Out:
# ...............................................................................................................................................

# %%
json.dump(data, open('data/genuis_data.json','w'), indent=2)

# %%
extract_feature_keys = {
    'danceability':'song_danceability',
    'energy':'song_energy',
    'key':'song_key',
    'loudness':'song_loudness',
    'mode': 'song_mode',
    'speechiness': 'song_speechiness',
    'acousticness': 'song_acousticness',
    'instrumentalness': 'song_instrumentalness',
    'liveness': 'song_liveness',
    'valence': 'song_valence',
    'tempo': 'song_tempo',
}

# %%
for i, (key,key_data) in enumerate(data.items()):
    feature = spotify.audio_features([key_data['song_id']])[0]
    try:
        for ex, ex_k in extract_feature_keys.items():
            data[key][ex_k] = feature[ex]
    except Exception as e:
        print(key)
        continue
    sleep(0.1)
    if i%10==0: print('.', end='')
# Out:
# ................................................................................................................................................

# %%
for i, (key,key_data) in enumerate(data.items()):
    album = spotify.albums([key_data['album_id']])['albums'][0]
    data[key]['album_popularity'] = album['popularity']
    data[key]['album_genres'] = album['genres']
    if i%10==0: print('.', end='')
# Out:
# ................................................................................................................................................

# %%
json.dump(data, open('data/genuis_data.json','w'), indent=2)

# %%
df = pd.DataFrame(data.values())
print(len(df))
df.head()
# Out:
# 1436
#               song       artist  song_billboard_rankings  \
# 0  Blinding Lights   The Weeknd              {'2020': 0}
# 1          Circles  Post Malone  {'2020': 1, '2019': 61}
# 2          The Box  Roddy Ricch              {'2020': 2}
# 3  Don’t Start Now     Dua Lipa              {'2020': 3}
# 4         ROCKSTAR       DaBaby              {'2020': 4}
#
#                                      song_genius_url  \
# 0  https://genius.com/the-weeknd-blinding-lights-...
# 1      https://genius.com/post-malone-circles-lyrics
# 2      https://genius.com/roddy-ricch-the-box-lyrics
# 3  https://genius.com/dua-lipa-dont-start-now-lyrics
# 4          https://genius.com/dababy-rockstar-lyrics
#
#                                          song_lyrics                album_id  \
# 0  Yeah\nI've been tryna call\nI've been on my ow...  4yP0hdKOZPNshxUOjY0cZj
# 1  Oh, oh, oh\nOh,  oh, oh\nOh,  oh, oh, oh, oh\n...  4g1ZRSobMefqF6nelkgibi
# 2  Pullin' out the coupe at the lot\nTold 'em fuc...  52u4anZbHd6UInnmHRFzba
# 3  If you don't wanna see me\nDid a full one-eigh...  5iO3erM9U06Ph7MNqaxVEo
# 4  Woo, woo\nI pull up like\nHow you pull up, Bab...  623PL2MBg50Br5dLXC9E9e
#
#    album_total_tracks  song_duration  song_explicit                 song_id  \
# 0                  14         200040          False  0VjIjW4GlUZAMYd2vXMi3b
# 1                  17         215280          False  21jGcNKet2qwijlDFuPiPb
# 2                  16         196652           True  0nbXyq5TXYPCO7pr3N8S4I
# 3                   1         267253          False  7cYNQkJoyHVhP8Drb2n6d5
# 4                  13         181733           True  7ytR5pFWmSjzHJIeQkgog4
#
#    ...  song_speechiness  song_acousticness  song_instrumentalness  \
# 0  ...            0.0598            0.00146               0.000095
# 1  ...            0.0395            0.19200               0.002440
# 2  ...            0.0559            0.10400               0.000000
# 3  ...            0.0569            0.00168               0.008140
# 4  ...            0.1640            0.24700               0.000000
#
#    song_liveness  song_valence  song_tempo  album_popularity  album_genres  \
# 0         0.0897         0.334     171.005                98            []
# 1         0.0863         0.553     120.042                93            []
# 2         0.7900         0.642     116.971                87            []
# 3         0.0809         0.673     114.988                37            []
# 4         0.1010         0.497      89.977                86            []
#
#                               album_name                         key
# 0                            After Hours  the-weeknd-blinding-lights
# 1                   Hollywood's Bleeding         post-malone-circles
# 2  Please Excuse Me For Being Antisocial         roddy-ricch-the-box
# 3     Don’t Start Now (Kaytranada Remix)     dua-lipa-dont-start-now
# 4                       BLAME IT ON BABY             dababy-rockstar
#
# [5 rows x 26 columns]

# %%
columns_order = [
    'key', 'song', 'artist', 
    'album_id', 'album_total_tracks', 'album_popularity', 'album_genres', 'album_name',
    'song_billboard_rankings', 'song_genius_url', 'song_duration', 'song_explicit', 
    'song_id', 'song_popularity', 'song_danceability', 'song_energy', 'song_key', 'song_loudness',
    'song_mode', 'song_speechiness', 'song_acousticness', 'song_instrumentalness', 'song_liveness',
    'song_valence', 'song_tempo', 'song_lyrics'
 ]

# %%
df = df[columns_order]

# %%
df = df.drop('album_genres', axis=1)

# %%
billboard_rankings_range = range(2020, 1989, -1)
ranking_data = []
for i in df.iterrows():
    row = i[1]
    inner_data = {}
    for bill in billboard_rankings_range:
        inner_data['rankings'+str(bill)] = 0
        if str(bill) in row['song_billboard_rankings']:
            inner_data['rankings'+str(bill)] = row['song_billboard_rankings'][str(bill)]+1
    ranking_data.append(inner_data)

# %%
df = pd.concat([df, pd.DataFrame(ranking_data)], axis=1)

# %%
df = df.drop('song_billboard_rankings', axis=1)

# %%
columns_order = [
    'key', 'song', 'artist', 
    'album_id', 'album_total_tracks', 'album_popularity','album_name',
    'song_genius_url', 'song_duration', 'song_explicit', 
    'song_id', 'song_popularity', 'song_danceability', 'song_energy', 'song_key', 'song_loudness',
    'song_mode', 'song_speechiness', 'song_acousticness', 'song_instrumentalness', 'song_liveness',
    'song_valence', 'song_tempo', 
    'rankings2020', 'rankings2019', 'rankings2018', 'rankings2017', 'rankings2016', 'rankings2015', 
    'rankings2014', 'rankings2013', 'rankings2012', 'rankings2011', 'rankings2010', 'rankings2009',
    'rankings2008', 'rankings2007', 'rankings2006', 'rankings2005', 'rankings2004', 'rankings2003', 
    'rankings2002', 'rankings2001', 'rankings2000', 'rankings1999', 'rankings1998', 'rankings1997',
    'rankings1996', 'rankings1995', 'rankings1994', 'rankings1993', 'rankings1992', 'rankings1991', 
    'rankings1990',
    'song_lyrics'
 ]
df = df[columns_order]

# %%
change_columns_name = [
    'key', 'song', 'artist', 
    'album_id', 'album_total_tracks', 'album_popularity','album_name',
    'song_genius_url', 'song_duration', 'song_explicit', 
    'song_id', 'song_popularity', 'song_danceability', 'song_energy', 'song_key', 'song_loudness',
    'song_mode', 'song_speechiness', 'song_acousticness', 'song_instrumentalness', 'song_liveness',
    'song_valence', 'song_tempo', 
    'song_ranking_2020', 'song_ranking_2019', 'song_ranking_2018', 'song_ranking_2017', 'song_ranking_2016', 
    'song_ranking_2015', 'song_ranking_2014', 'song_ranking_2013', 'song_ranking_2012', 'song_ranking_2011', 
    'song_ranking_2010', 'song_ranking_2009','song_ranking_2008', 'song_ranking_2007', 'song_ranking_2006', 
    'song_ranking_2005', 'song_ranking_2004', 'song_ranking_2003', 'song_ranking_2002', 'song_ranking_2001', 
    'song_ranking_2000', 'song_ranking_1999', 'song_ranking_1998', 'song_ranking_1997', 'song_ranking_1996', 
    'song_ranking_1995', 'song_ranking_1994', 'song_ranking_1993', 'song_ranking_1992', 'song_ranking_1991', 
    'song_ranking_1990',
    'song_lyrics'
 ]
df.columns = change_columns_name

# %%
df.to_json('data/genuis_data.json', orient='records')
df.to_csv('data/genuis_data.csv', index=False)
